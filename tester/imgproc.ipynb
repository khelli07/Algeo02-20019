# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Read Picture

# %%
img = cv.imread('lena.png')
gray_img = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
plt.imshow(img)
plt.show()

# %%
matrix = np.asarray(gray_img)
print(matrix.shape)
matrix
# Out:
# (850, 850)
# array([[250, 220, 222, ..., 226, 222, 220],
#        [222,  81,  90, ..., 107,  87,  79],
#        [222,  88,  96, ..., 111,  93,  85],
#        ...,
#        [186,   5,   9, ...,  35,  35,  35],
#        [186,   5,   9, ...,  36,  37,  37],
#        [186,   5,   9, ...,  37,  37,  37]], dtype=uint8)

# %%
plt.imshow(matrix, cmap='gray')
plt.show()
